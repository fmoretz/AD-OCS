# %%
from Discretizz_forward import *
# Out:
# ***Intervals of 0.01 hours.
#  6001 time steps***
# Simulation is on going...
#           t  t_out    F_CH4   F_CO2     F_H2S      F_O2       F_H2O  \
# 1      0.01   4.31  2537.39  706.49  1.509990  0.699993  181.030010
# 2      0.02   4.32  2537.39  706.49  1.509979  0.699985  181.030021
# 3      0.03   4.33  2537.39  706.49  1.509969  0.699978  181.030031
# 4      0.04   4.34  2537.39  706.49  1.509959  0.699971  181.030041
# 5      0.05   4.35  2537.39  706.49  1.509949  0.699963  181.030051
# ...     ...    ...      ...     ...       ...       ...         ...
# 5996  59.96  64.26  2537.39  706.49  2.152758  0.342798  181.749117
# 5997  59.97  64.27  2537.39  706.49  2.152759  0.342798  181.749117
# 5998  59.98  64.28  2537.39  706.49  2.152759  0.342798  181.749117
# 5999  59.99  64.29  2537.39  706.49  2.152759  0.342798  181.749118
# 6000  60.00  64.30  2537.39  706.49  2.152759  0.342798  181.749118
#
# ...

# %%
t = digester_out['t']
plt.plot(t, digester_out['efficiency'], label='efficiency')
plt.plot(t, r_SOB)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# c:\Users\fede1\OneDrive - Politecnico di Milano\Documenti\GitHub\AD-OCS\AD-OCS\Old Versions\NEW Sulfur\V6 - New Oxygen\V6.7 - New_CSTR\prova_control.ipynb Cell 2 in <cell line: 3>()
#       <a href='vscode-notebook-cell:/c%3A/Users/fede1/OneDrive%20-%20Politecnico%20di%20Milano/Documenti/GitHub/AD-OCS/AD-OCS/Old%20Versions/NEW%20Sulfur/V6%20-%20New%20Oxygen/V6.7%20-%20New_CSTR/prova_control.ipynb#X15sZmlsZQ%3D%3D?line=0'>1</a> t = digester_out['t']
#       <a href='vscode-notebook-cell:/c%3A/Users/fede1/OneDrive%20-%20Politecnico%20di%20Milano/Documenti/GitHub/AD-OCS/AD-OCS/Old%20Versions/NEW%20Sulfur/V6%20-%20New%20Oxygen/V6.7%20-%20New_CSTR/prova_control.ipynb#X15sZmlsZQ%3D%3D?line=1'>2</a> plt.plot(t, digester_out['efficiency'], label='efficiency')
# ...
