# %%
from main_7 import *
# Out:
# Choose a datasets:
#  1 -> AMOCO_HN
#  2 -> provaADM1
#  3 -> bsm2
#  4 -> matlab
#  5 -> thoni
# Data are from: thoni
# mu1,max: 0.353090615277312; Ks1:  0.5541854402140335; Cd1: 0.05411864227041188
# mu2,max: 0.20883039488671676; Ks2:  1.2743639393588828; KI2: 75971945.92171845; Cd2: 0.1700147020969962
# k1: [29.05329558], intercept: -0.2820358859986558
# k2: [39.033739], intercept: 0.5097516659788752
# k3: [52.07859156], intercept: 0.5097516659788752
# k4: [130.73983013], intercept: 0.0
# k5: [216.67238778], intercept: 0.0
# k6: [283.70526885], intercept: -6.330647631894543
# k_hyd: [0.41697676], intercept: -0.07858581425180367
# kLa: [76.28997915],     intercept: -115.93737975487875,
#
#  STEADY STATE VALUES
#
# S.S. of XT   6.007890443548926
# S.S. of X1   0.9471914593854454
# S.S. of X2   0.5839314137417821
# S.S. of Z    225.63602393879688
# S.S. of S1   0.19110212047087882
# S.S. of S2   1.3373360746509833
# S.S. of C    231.59317642252282
# S.S. of CO2  7.2944885583769254
# ...

# %%
digester_out['x_v_CH4']
# Out:
# 0      0.630057
# 1      0.630138
# 2      0.630219
# 3      0.630297
# 4      0.630374
#          ...
# 736    0.631102
# 737    0.631104
# 738    0.631107
# 739    0.631109
# 740    0.631111
# Name: x_v_CH4, Length: 741, dtype: float64

# %%
60.5
60.7
61.1
62.0
61.9
61.8
61.1
61.0
60.7
60.0
59.9
60.3
60.4
60.1
60.2
60.0
60.4
59.4
60.7
60.6
60.5
59.9
59.5
58.7
58.9
59.9
59.2
59.2
60.5
60.1
59.1

# %%
plt.title('OUR MODEL')
plt.plot(digester_out["t"]/24, digester_out["x_v_CH4"].rolling(30).mean())
plt.grid()
plt.xlabel("Time [days]")
plt.ylabel("CH4 [%]")
# Out:
# Text(0, 0.5, 'CH4 [%]')

# %%
# reorder the columns of T3
T3_m = pd.DataFrame()
T3_m["S1in"] = T3["S1in"]
T3_m["S2in"] = T3["S2in"]
T3_m["Cin"] = T3["Cin"]
T3_m["Nin"] = T3["Nin"]
T3_m["XTin"] = T3["XTin"]
T3_m["Qin"] = T3["Qin"]
T3 = T3_m
